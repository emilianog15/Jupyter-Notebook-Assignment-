# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Emiliano Gonzalez**
#
# Desired occupation: Data scientist.

# %% [markdown]
# *I'm interested in data science because I've always wanted to learn to solve problems using evidence. Also I've always been interested in statistics and technology.*

# %% [markdown]
# ### My code will take a temperature in Fahrenheit and return the equivalent in Celsius.

# %%
fahr=input("Please enter a temperature in Fahrenheit")
cel=(int(fahr)-32)/1.8
print(str(fahr)+" Fahrenheit degrees is equivalent to " +str(cel)+" Celsius degrees.")
# Out:
# Please enter a temperature in Fahrenheit 89
# 89 Fahrenheit degrees is equivalent to 31.666666666666664 Celsius degrees.

# %% [markdown]
# ***
# | pet 1 | pet 2 | pet 3 |
# | --- | --- | --- |
# | cat | dog | fish |
# | cute | friendly | slimy |
# ***
# ![2297337-bigthumbnail-1760383269.jpeg](attachment:a438e2f1-099b-450d-83bd-643e4704867f.jpeg)
